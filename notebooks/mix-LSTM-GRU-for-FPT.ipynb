# %%
from vnstock import *
# Out:
# **Vui lòng chuyển đổi sang Vnstock3** thế hệ mới (3.1.0) với câu lệnh: `pip install vnstock3 --upgrade`.
# **Từ 1/1/2025, vnstock3 sẽ được cài đặt khi sử dụng cú pháp** `pip install vnstock` **thay cho Vnstock Legacy** hiện tại.
# Xem chi tiết [chuyển đổi sang vnstock3](https://vnstocks.com/docs/tai-lieu/migration-chuyen-doi-sang-vnstock3).
# Phiên bản **Vnstock Legacy (0.2.9.2.3)** bạn đang sử dụng **sẽ không được nâng cấp thêm.**
# Từ 7/10/2024 Vnstock giới thiệu nhóm Facebook Cộng đồng Vnstock, tham gia thảo luận tại đây: https://www.facebook.com/groups/vnstock.official

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error
import os
import random

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import LSTM, Flatten, Dense, Masking, GRU
from tensorflow.keras.models import Sequential
from scikeras.wrappers import KerasRegressor
from sklearn.preprocessing import MinMaxScaler
from keras.callbacks import EarlyStopping
from sklearn.metrics import r2_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
seed_value = 32  # Bạn có thể thay đổi seed theo ý muốn

os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
start_date='2015-01-01'
end_date='2024-12-18'
df=stock_historical_data('FPT',start_date,end_date)
#df=pd.read_csv('FPT.csv',index_col=0)

# %%
#df.to_csv("FPT.csv")

# %%
df.columns=['time','close','open','high','low','volume','%']

# %%
df
# Out:
#             time   close    open    high     low   volume    %
# 0     2015-01-05    8750    8790    8670    8710   273550  FPT
# 1     2015-01-06    8650    8770    8620    8770   364050  FPT
# 2     2015-01-07    8770    8960    8770    8830   405560  FPT
# 3     2015-01-08    8800    8830    8710    8730   227300  FPT
# 4     2015-01-09    8730    8840    8730    8800   320210  FPT
# ...          ...     ...     ...     ...     ...      ...  ...
# 2483  2024-12-11  150000  151700  149700  150500  4816600  FPT
# 2484  2024-12-12  151900  151900  149200  150200  4147900  FPT
# 2485  2024-12-13  149500  150900  149400  149500  3379800  FPT
# 2486  2024-12-16  149600  150600  149500  149900  3291100  FPT
# 2487  2024-12-17  150100  150500  147700  148000  5947500  FPT
#
# [2488 rows x 7 columns]

# %%
df.set_index('time',inplace=True)
#Nếu dùng cho cổ phiếu thì dùng:
df.index=pd.to_datetime(df.index,format='%Y-%m-%d')
#Nếu dùng cho VNINDEX thì dùng
#df.index=pd.to_datetime(df.index,format='%d/%m/%Y')
df=df.sort_values('time')

# %%
pos_df=df.reset_index()

# %%
index_pos=pos_df[pos_df['time']=='2023-12-30'].index[0]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
df['scaled_close']=scaler.fit_transform(df[['close']])

# %%
# Lấy giá đóng cửa
#Cho giá cổ phiếu
#train_data = df[['close']].iloc[:'2022-12-31'].values
#test_data = df[['close']].iloc['2023-01-01':'2023-12-31'].values
#Cho VNINDEX
train_data = df[['scaled_close']].iloc[:index_pos].values
test_data = df[['scaled_close']].iloc[index_pos:].values

# Tạo tập dữ liệu cho mô hình LSTM
def create_multistep_dataset(data, time_step, predict_step):
    X, y = [], []
    for i in range(time_step, len(data) - predict_step + 1):
        X.append(data[i-time_step:i, 0])  # Lấy 50 ngày trước đó làm đầu vào
        y.append(data[i:i+predict_step, 0])  # Lấy 5 ngày tiếp theo làm đầu ra
    return np.array(X), np.array(y)

time_step = 20
predict_step = 1
X_train, y_train = create_multistep_dataset(train_data, time_step, predict_step)
X_test, y_test = create_multistep_dataset(test_data, time_step, predict_step)

# Reshape dữ liệu cho LSTM [samples, time_steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model_mix = Sequential([
    LSTM(units=256, return_sequences=True, input_shape=(time_step, 1)),  # LSTM layer đầu tiên
    GRU(units=256, return_sequences=False),
    Dense(units=256),
    Dense(units=predict_step)
])
# Compile mô hình
model_mix.compile(optimizer='adam', loss='mean_absolute_error')

# Huấn luyện mô hình
model_mix.fit(X_train, y_train, batch_size=32, epochs=100,shuffle=True)
# Out:
# Epoch 1/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - loss: 0.0637
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0112
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0118
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0076
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0072
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - loss: 0.0072
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0072
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0062
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0083
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0065
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 0.0076
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0055
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - loss: 0.0059
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0056
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0067
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0059
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.0073
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - loss: 0.0073
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - loss: 0.0057
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0067
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0064
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0057
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0054
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0064
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0070
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0067
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0062
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0050
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0058
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0058
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 105ms/step - loss: 0.0057
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0053
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0065
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0059
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0054
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0068
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0051
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.0052
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - loss: 0.0054
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0052
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - loss: 0.0054
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 117ms/step - loss: 0.0068
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - loss: 0.0054
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0052
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - loss: 0.0057
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0058
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0058
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0055
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0053
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - loss: 0.0058
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 0.0050
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0049
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0056
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0062
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 0.0052
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0049
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0057
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0050
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 0.0053
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0061
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0051
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - loss: 0.0054
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - loss: 0.0048
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - loss: 0.0059
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0055
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - loss: 0.0050
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - loss: 0.0060
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0053
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0059
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0057
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - loss: 0.0049
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0051
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - loss: 0.0047
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0051
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0058
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - loss: 0.0051
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 0.0059
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 0.0062
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - loss: 0.0053
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0053
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0046
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0057
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0050
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0045
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0052
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 106ms/step - loss: 0.0055
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - loss: 0.0048
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 111ms/step - loss: 0.0048
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 0.0050
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0054
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 0.0054
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0049
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0045
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 113ms/step - loss: 0.0048
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0051
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0050
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 0.0048
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 116ms/step - loss: 0.0044
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 114ms/step - loss: 0.0045
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.0052

# %%
# Dự đoán giá
yhat_train_mix = model_mix.predict(X_train)
yhat_test_mix = model_mix.predict(X_test)

# Đảo ngược chuẩn hóa
yhat_train_mix = scaler.inverse_transform(yhat_train_mix)
yhat_test_mix = scaler.inverse_transform(yhat_test_mix)
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
y_train_plot=scaler.inverse_transform(y_train)
y_test_plot=scaler.inverse_transform(y_test)

# %%
MSE_train=[mean_squared_error(y_train_plot,yhat_train_mix)]
RMSE_train=[root_mean_squared_error(y_train_plot,yhat_train_mix)]
MAE_train=[mean_absolute_error(y_train_plot,yhat_train_mix)]
R2_train=[r2_score(y_train_plot,yhat_train_mix)]
error_train_table=pd.DataFrame({'R2':R2_train,
                                'MSE':MSE_train,
                                'RMSE':RMSE_train,
                               'MAE':MAE_train})
error_train_table.index=['FPT']

# %%
MSE_test=[mean_squared_error(y_test_plot,yhat_test_mix)]
RMSE_test=[root_mean_squared_error(y_test_plot,yhat_test_mix)]
MAE_test=[mean_absolute_error(y_test_plot,yhat_test_mix)]
R2_test=[r2_score(y_test_plot,yhat_test_mix)]
error_test_table=pd.DataFrame({'R2':R2_test,
                                'MSE':MSE_test,
                                'RMSE':RMSE_test,
                               'MAE':MAE_test})
error_test_table.index=['FPT']

# %%
error_train_table.round(6)
# Out:
#            R2            MSE        RMSE         MAE
# FPT  0.998359  504979.365821  710.619002  482.365724

# %%
error_test_table.round(6)
# Out:
#            R2           MSE         RMSE          MAE
# FPT  0.983806  2.532363e+06  1591.340083  1154.558418

# %%
y_train_draw=y_train_plot.reshape(y_train_plot.shape[0],)
yhat_train_mix_draw=yhat_train_mix.reshape(yhat_train_mix.shape[0],)

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=[20,30])
    plt.subplot(3,1,1)
    plt.title('Kết quả dự đoán mô hình LSTM-GRU')
    plt.plot(y_train_draw,label='Thực tế')
    plt.plot(yhat_train_mix_draw,label='Dự đoán')
    plt.legend()
    plt.show()

# %%
y_test_draw=y_test_plot.reshape(y_test_plot.shape[0],)
yhat_test_mix_draw=yhat_test_mix.reshape(yhat_test_mix.shape[0],)

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=[20,30])
    plt.subplot(3,1,1)
    plt.title('Kết quả dự đoán mô hình LSTM-GRU')
    plt.plot(y_test_draw,label='Thực tế')
    plt.plot(yhat_test_mix_draw,label='Dự đoán')
    plt.legend()
    plt.show()
